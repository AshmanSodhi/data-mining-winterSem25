# %%
import datetime as dt
def printDN():
    print(dt.datetime.now())
    print("Ashman Sodhi - 23BDS0068")

# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from sklearn.naive_bayes import CategoricalNB
printDN()
# Out:
# 2026-02-20 00:41:17.041522
# Ashman Sodhi - 23BDS0068

# %%
df = pd.read_csv("weather.csv")

X = df.drop("Class", axis=1)
y = df["Class"]
printDN()
# Out:
# 2026-02-20 00:41:18.941618
# Ashman Sodhi - 23BDS0068

# %%
#Encoder
encoder = OrdinalEncoder()
X_encoded = encoder.fit_transform(X)
printDN()
# Out:
# 2026-02-20 00:41:20.805718
# Ashman Sodhi - 23BDS0068

# %%
# Train model
model = CategoricalNB()
model.fit(X_encoded, y)
printDN()
# Out:
# 2026-02-20 00:41:22.776186
# Ashman Sodhi - 23BDS0068

# %%
# IMPORTANT: column name must match CSV EXACTLY
sample = pd.DataFrame([["overcast","cool","normal",True]],
                      columns=X.columns)

# Encode sample
sample_encoded = encoder.transform(sample)

# Predict
prediction = model.predict(sample_encoded)

print("Prediction:", prediction[0])
printDN()
# Out:
# Prediction: P
# 2026-02-20 00:41:24.993389
# Ashman Sodhi - 23BDS0068
