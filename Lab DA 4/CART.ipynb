# %%
import datetime as dt
def printDN():
    print(dt.datetime.now())
    print("Ashman Sodhi - 23BDS0068")

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
printDN()
# Out:
# 2026-03-10 20:40:03.894375
# Ashman Sodhi - 23BDS0068

# %%
df = pd.read_csv("tennis_data.csv")
printDN()
# Out:
# 2026-03-10 20:40:03.931132
# Ashman Sodhi - 23BDS0068

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
printDN()
# Out:
# 2026-03-10 20:40:03.950274
# Ashman Sodhi - 23BDS0068

# %%
encoders = {}

for column in df.columns:
    df[column] = le.fit_transform(df[column])
    encoders[column] = le
    
    print(f"\nEncoding for {column}:")
    for i, label in enumerate(le.classes_):
        print(label, "->", i)

printDN()
# Out:
# Encoding for Outlook:
# Overcast -> 0
# Rainy -> 1
# Sunny -> 2
#
# Encoding for Temperature:
# Cool -> 0
# Hot -> 1
# Mild -> 2
#
# Encoding for Humidity:
# High -> 0
# Normal -> 1
#
# Encoding for Windy:
# False -> 0
# True -> 1
#
# Encoding for PlayTennis:
# No -> 0
# Yes -> 1
# 2026-03-10 20:40:03.971401
# Ashman Sodhi - 23BDS0068

# %%
col_names = ['Outlook', 'Temperature', 'Humidity', 'Windy']
printDN()
# Out:
# 2026-03-10 20:40:04.073438
# Ashman Sodhi - 23BDS0068

# %%
x = df[col_names]
y = df.PlayTennis
printDN()
# Out:
# 2026-03-10 20:40:04.094558
# Ashman Sodhi - 23BDS0068

# %%
#data split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
printDN()
# Out:
# 2026-03-10 20:40:04.114673
# Ashman Sodhi - 23BDS0068

# %%
#creating id3 tree object
clf = DecisionTreeClassifier(criterion="gini")

#training the tree
clf = clf.fit(X_train,y_train)

#predicting for test data
y_pred = clf.predict(X_test)

printDN()
# Out:
# 2026-03-10 20:40:04.189516
# Ashman Sodhi - 23BDS0068

# %%
y_pred
printDN()
# Out:
# 2026-03-10 20:40:04.202369
# Ashman Sodhi - 23BDS0068

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
printDN()
# Out:
# Accuracy: 0.6
# 2026-03-10 20:40:04.215303
# Ashman Sodhi - 23BDS0068

# %%
sample = [[2, 1, 0, 0]]
prediction = clf.predict(sample)
printDN()
# Out:
# 2026-03-10 20:40:04.245339
# Ashman Sodhi - 23BDS0068
# C:\Users\ASHMAN SODHI\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction
printDN()
# Out:
# 2026-03-10 20:40:04.261337
# Ashman Sodhi - 23BDS0068
