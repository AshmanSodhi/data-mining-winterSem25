# %%
import datetime as dt
def printDN():
    print(dt.datetime.now())
    print("Ashman Sodhi - 23BDS6068")

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
printDN()
# Out:
# 2026-03-10 23:17:23.260023
# Ashman Sodhi - 23BDS6068

# %%
# Dataset
data = np.array([
[2,10],
[2,6],
[11,11],
[6,9],
[6,4],
[1,2],
[5,10],
[4,9],
[10,12],
[7,5],
[9,11],
[4,6],
[3,10],
[3,8],
[6,11]
])

df = pd.DataFrame(data, columns=['X','Y'])
printDN()
# Out:
# 2026-03-10 23:17:23.325837
# Ashman Sodhi - 23BDS6068

# %%
initial_centroids = np.array([
[2,6],
[5,10],
[6,11]
])
printDN()
# Out:
# 2026-03-10 23:17:23.331194
# Ashman Sodhi - 23BDS6068

# %%
# Apply K-Means
kmeans = KMeans(
    n_clusters=3,
    init=initial_centroids,
    n_init=1
)

kmeans.fit(df)

# Cluster labels
df['Cluster'] = kmeans.labels_
printDN()
# Out:
# 2026-03-10 23:17:26.263322
# Ashman Sodhi - 23BDS6068

# %%
print("Clustered Data:")
print(df)

print("\nFinal Centroids:")
print(kmeans.cluster_centers_)

# Plot clusters
plt.scatter(df['X'], df['Y'], c=df['Cluster'])
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1])
plt.xlabel("X")
plt.ylabel("Y")
plt.title("K-Means with Initial Centroids")
plt.show()
printDN()
# Out:
# Clustered Data:
#      X   Y  Cluster
# 0    2  10        1
# 1    2   6        0
# 2   11  11        2
# 3    6   9        1
# 4    6   4        0
# 5    1   2        0
# 6    5  10        1
# 7    4   9        1
# 8   10  12        2
# 9    7   5        0
# 10   9  11        2
# 11   4   6        0
# 12   3  10        1
# 13   3   8        1
# 14   6  11        1
#
# Final Centroids:
# [[ 4.          4.6       ]
#  [ 4.14285714  9.57142857]
#  [10.         11.33333333]]
# 2026-03-10 23:17:26.392947
# Ashman Sodhi - 23BDS6068
