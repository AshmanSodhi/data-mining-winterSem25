# %%
import datetime as dt
def printDN():
    print(dt.datetime.now())
    print("Ashman Sodhi - 23BDS6068")

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# %%
data = {
    "Brightness": [40, 50, 60, 10, 70, 60, 25],
    "Saturation": [20, 50, 90, 25, 70, 10, 80],
    "Class": ["Red", "Blue", "Blue", "Red", "Blue", "Red", "Blue"]
}

df = pd.DataFrame(data)
printDN()
# Out:
# 2026-03-10 20:11:19.455346
# Ashman Sodhi - 23BDS6068

# %%
X = df[["Brightness", "Saturation"]]
y = df["Class"]
printDN()
# Out:
# 2026-03-10 20:11:19.471811
# Ashman Sodhi - 23BDS6068

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X, y)
printDN()
# Out:
# 2026-03-10 20:11:19.490900
# Ashman Sodhi - 23BDS6068

# %%
new_point = [[20, 35]]

prediction = knn.predict(new_point)
print("Predicted Class:", prediction[0])
printDN()
# Out:
# Predicted Class: Red
# 2026-03-10 20:11:19.503611
# Ashman Sodhi - 23BDS6068
# C:\Users\ASHMAN SODHI\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
