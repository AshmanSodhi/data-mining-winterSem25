# %%
import datetime as dt
def printDN():
    print(dt.datetime.now())
    print("Ashman Sodhi - 23BDS0068")

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Mall_Customers.csv")
printDN()
# Out:
# 2026-03-10 23:54:35.637583
# Ashman Sodhi - 23BDS0068

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df=df.drop(['CustomerID'],axis=1)
df.rename(columns={'Annual Income (k$)':'Income','Spending Score (1-100)':'SpendScore'},inplace=True)
printDN()
# Out:
# 2026-03-10 23:54:35.657300
# Ashman Sodhi - 23BDS0068

# %%
df.head()
# Out:
#    Gender  Age  Income  SpendScore
# 0    Male   19      15          39
# 1    Male   21      15          81
# 2  Female   20      16           6
# 3  Female   23      16          77
# 4  Female   31      17          40

# %%
x=df.iloc[:,[2,3]].values

# %%
print(x.shape)
printDN()
# Out:
# (200, 2)
# 2026-03-10 23:54:35.670122
# Ashman Sodhi - 23BDS0068

# %%
from sklearn.cluster import DBSCAN
db=DBSCAN(eps=3,min_samples=4,metric='euclidean')
printDN()
# Out:
# 2026-03-10 23:54:35.673369
# Ashman Sodhi - 23BDS0068

# %%
model=db.fit(x)
label=model.labels_

# %%
from sklearn import metrics

sample_cores=np.zeros_like(label,dtype=bool)
sample_cores[db.core_sample_indices_]=True

n_clusters=len(set(label))- (1 if -1 in label else 0)
print('No of clusters:',n_clusters)
printDN()
# Out:
# No of clusters: 9
# 2026-03-10 23:54:35.682159
# Ashman Sodhi - 23BDS0068

# %%
y_means = db.fit_predict(x)
plt.figure(figsize=(7,5))
plt.scatter(x[y_means == 0, 0], x[y_means == 0, 1], s = 50, c = 'pink')
plt.scatter(x[y_means == 1, 0], x[y_means == 1, 1], s = 50, c = 'yellow')
plt.scatter(x[y_means == 2, 0], x[y_means == 2, 1], s = 50, c = 'cyan')
plt.scatter(x[y_means == 3, 0], x[y_means == 3, 1], s = 50, c = 'magenta')
plt.scatter(x[y_means == 4, 0], x[y_means == 4, 1], s = 50, c = 'orange')
plt.scatter(x[y_means == 5, 0], x[y_means == 5, 1], s = 50, c = 'blue')
plt.scatter(x[y_means == 6, 0], x[y_means == 6, 1], s = 50, c = 'red')
plt.scatter(x[y_means == 7, 0], x[y_means == 7, 1], s = 50, c = 'black')
plt.scatter(x[y_means == 8, 0], x[y_means == 8, 1], s = 50, c = 'violet')
plt.xlabel('Annual Income in (1k)')
plt.ylabel('Spending Score from 1-100')
plt.title('Clusters of data')
plt.show()
printDN()
# Out:
# 2026-03-10 23:54:35.786050
# Ashman Sodhi - 23BDS0068
